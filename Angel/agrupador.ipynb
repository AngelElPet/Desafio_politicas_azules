# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Formulario sin título.csv', encoding= 'utf-8')
del(df['Marca temporal'])

# %%
df.head()
# Out:
#   Elige la comunidad autónoma en la que vives:  \
# 0                                    Andalucía
# 1                                       Madrid
# 2                                    Andalucía
# 3                                    Andalucía
# 4                                    Andalucía
#
#            ¿Qué son las políticas azules?  \
# 0  Las políticas relacionadas con el agua
# 1  Las políticas relacionadas con el agua
# 2  Las políticas relacionadas con el agua
# 3  Las políticas relacionadas con el agua
# 4  Las políticas relacionadas con el agua
#
#   ¿Qué Ministerio gestiona las políticas relacionadas con el agua?  \
# 0                               Transición Ecológica
# 1                               Transición Ecológica
# 2                                            Consumo
# 3                               Transición Ecológica
# 4                               Transición Ecológica
#
#   ¿Quién tiene la titularidad de la gestión del agua?  \
# ...

# %% [markdown]
# 1.- ¿que son las politicas azules:
# a.- 0.5
# b.- 1
# c.- 0.1
# d.- 0.2

# %%
lista2 = []
lista1 = list(df['¿Qué son las políticas azules?'])
for x in range(len(lista1)):
    if lista1[x] == 'Las políticas relacionadas con el cielo':
        lista2.append(0.5*10)
    elif lista1[x] == 'Las políticas relacionadas con el agua':
        lista2.append(10)
    elif lista1[x] == 'Las políticas relacionadas con los colores':
        lista2.append(0.1*10)
    else:
        lista2.append(0.2*10)

df['Respuesta1'] = lista2

# %% [markdown]
# 1.- ¿que son las politicas azules:
# a.- 0.5
# b.- 1
# c.- 0.1
# d.- 0.2
# 2.- Ministerio que gestiona el agua
# a.- 1
# b.- 0.1
# c.- 0.5
# d.- 0.2

# %%
lista0 = []
lista1 = list(df['¿Qué Ministerio gestiona las políticas relacionadas con el agua?'])
for x in range(len(lista1)):
    if lista1[x] == 'Transición Ecológica':
            lista0.append(10)
    elif lista1[x] =='Interior':
        lista0.append(0.1*10)
    elif lista1[x] == 'Exteriores':
        lista0.append(0.5*10)
    else:
        lista0.append(0.2*10)

df['Respuesta2'] = lista0

# %% [markdown]
# 1.- ¿que son las politicas azules:
# a.- 0.5
# b.- 1
# c.- 0.1
# d.- 0.2
# 2.- Ministerio que gestiona el agua
# a.- 1
# b.- 0.1
# c.- 0.5
# d.- 0.2
# 3.- Gestión del agua
# 1.-0.1
# 2.- 1

# %%
lista3 = []
lista1 = list(df['¿Quién tiene la titularidad de la gestión del agua?'])
for x in range(len(lista1)):
    if lista1[x] == 'Titularidad privada':
        lista3.append(0.1*10)
    elif lista1[x] =='Titularidad pública':
        lista3.append(10)

df['Respuesta3'] = lista3

# %% [markdown]
# 1.- ¿que son las politicas azules:
# a.- 0.5
# b.- 1
# c.- 0.1
# d.- 0.2
# 2.- Ministerio que gestiona el agua
# a.- 1
# b.- 0.1
# c.- 0.5
# d.- 0.2
# 3.- Gestión del agua
# 1.-0.1
# 2.- 1
# 4.-Consumo de litro por persona
# 1.- 0.5
# 2.- 0.2
# 3.- 1
# 4.- 0.1

# %%
lista4 = []
lista1 = list(df['En las últimas dos décadas ¿cuántos litros de agua crees que consume de media una persona en su casa?'])
for x in range(len(lista1)):
    if lista1[x] == '33.8':
        lista4.append(10*0.5)
    elif lista1[x] =='53.4':
        lista4.append(0.2*10)
    elif lista1[x] == '39.3':
        lista4.append(10)
    else:
        lista4.append(0.1*10)

df['Respuesta4'] = lista4

# %% [markdown]
# 1.- ¿que son las politicas azules:
# a.- 0.5
# b.- 1
# c.- 0.1
# d.- 0.2
# 2.- Ministerio que gestiona el agua
# a.- 1
# b.- 0.1
# c.- 0.5
# d.- 0.2
# 3.- Gestión del agua
# 1.-0.1
# 2.- 1
# 4.-Consumo de litro por persona
# 1.- 0.5
# 2.- 0.2
# 3.- 1
# 4.- 0.1
# 5.- Embalses más vacio
# 1.- 0.2
# 2.- 0.5
# 3.- 0.1
# 4.- 1

# %%
lista5 = []
lista1 = list(df['En mayo de 2023 ¿cuál es la comunidad autónoma que tiene los embalses más vacíos?'])
for x in range(len(lista1)):
    if lista1[x] == 'Extremadura':
        lista5.append(10*0.2)
    elif lista1[x] =='Cataluña':
        lista5.append(0.5*10)
    elif lista1[x] == 'Asturias':
        lista5.append(0.1*10)
    else:
        lista5.append(10)

df['Respuesta5'] = lista5

# %% [markdown]
# 1.- ¿que son las politicas azules:
# a.- 0.5
# b.- 1
# c.- 0.1
# d.- 0.2
# 2.- Ministerio que gestiona el agua
# a.- 1
# b.- 0.1
# c.- 0.5
# d.- 0.2
# 3.- Gestión del agua
# 1.-0.1
# 2.- 1
# 4.-Consumo de litro por persona
# 1.- 0.5
# 2.- 0.2
# 3.- 1
# 4.- 0.1
# 5.- Embalses más vacio
# 1.- 0.2
# 2.- 0.5
# 3.- 0.1
# 4.- 1
# 6.- Cual es la cuenca que más embalses tiene en España
# 1.- 0.1
# 2.- 1
# 3.-0.5
# 4.- 0.2

# %%
lista6 = []
lista1 = list(df['¿Cuál es la cuenca que más embalses tiene en España?'])
for x in range(len(lista1)):
    if lista1[x] == 'Cuenca del Segura':
        lista6.append(0.1*10)
    elif lista1[x] =='Cuenca del Ebro':
        lista6.append(10)
    elif lista1[x] == 'Cuenca del Tajo':
        lista6.append(0.5*10)
    else:
        lista6.append(0.2*10)

df['Respuesta6'] = lista6

# %% [markdown]
# 1.- ¿que son las politicas azules:
# a.- 0.5
# b.- 1
# c.- 0.1
# d.- 0.2
# 2.- Ministerio que gestiona el agua
# a.- 1
# b.- 0.1
# c.- 0.5
# d.- 0.2
# 3.- Gestión del agua
# 1.-0.1
# 2.- 1
# 4.-Consumo de litro por persona
# 1.- 0.5
# 2.- 0.2
# 3.- 1
# 4.- 0.1
# 5.- Embalses más vacio
# 1.- 0.2
# 2.- 0.5
# 3.- 0.1
# 4.- 1
# 6.- Cual es la cuenca que más embalses tiene en España
# 1.- 0.1
# 2.- 1
# 3.-0.5
# 4.- 0.2
# 7.- Porcentaje de agua reutilizada
# 1.- 0.2
# 2.- 0.5
# 3.- 1
# 4.- 0.1

# %%
lista7 = []
lista1 = list(df['¿Cuál es la cuenca que más embalses tiene en España?'])
for x in range(len(lista1)):
    if lista1[x] == '25%':
        lista7.append(0.2*10)
    elif lista1[x] =='5%':
        lista7.append(0.5*10)
    elif lista1[x] == '9,96%':
        lista7.append(10)
    else:
        lista7.append(0.1*10)

df['Respuesta7'] = lista7

# %% [markdown]
# 1.- ¿que son las politicas azules:
# a.- 0.5
# b.- 1
# c.- 0.1
# d.- 0.2
# 2.- Ministerio que gestiona el agua
# a.- 1
# b.- 0.1
# c.- 0.5
# d.- 0.2
# 3.- Gestión del agua
# 1.-0.1
# 2.- 1
# 4.-Consumo de litro por persona
# 1.- 0.5
# 2.- 0.2
# 3.- 1
# 4.- 0.1
# 5.- Embalses más vacio
# 1.- 0.2
# 2.- 0.5
# 3.- 0.1
# 4.- 1
# 6.- Cual es la cuenca que más embalses tiene en España
# 1.- 0.1
# 2.- 1
# 3.-0.5
# 4.- 0.2
# 7.- Porcentaje de agua reutilizada
# 1.- 0.2
# 2.- 0.5
# 3.- 1
# 4.- 0.1
# 8.- Evolución de los estados de los embalses
# 1.- 1
# 2.- 0.1

# %%
lista8 = []
lista1 = list(df['¿Cómo crees que evolucionarán el estado de los embalses en el futuro?'])
for x in range(len(lista1)):
    if lista1[x] == 'Empeorará':
        lista8.append(10)
    elif lista1[x] =='Mejorará':
        lista8.append(0.2*10)


df['Respuesta8'] = lista8

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])
a+b
# Out:
# array([5, 7, 9])

# %%
lista0 = np.array(lista0)
lista2 = np.array(lista2)
lista3 = np.array(lista3)
lista4 = np.array(lista4)
lista5 = np.array(lista5)
lista6 = np.array(lista6)
lista7 = np.array(lista7)
lista8 = np.array(lista8)

lista_scoring = lista0+lista2+lista3+lista4+lista5+lista6+lista7+lista8
df['Scoring'] = lista_scoring

# %%
df
# Out:
#     Elige la comunidad autónoma en la que vives:  \
# 0                                      Andalucía
# 1                                         Madrid
# 2                                      Andalucía
# 3                                      Andalucía
# 4                                      Andalucía
# ..                                           ...
# 107                                     Valencia
# 108                                     Valencia
# 109                                     Cataluña
# 110                                      Galicia
# 111                                       Madrid
#
#              ¿Qué son las políticas azules?  \
# 0    Las políticas relacionadas con el agua
# 1    Las políticas relacionadas con el agua
# 2    Las políticas relacionadas con el agua
# 3    Las políticas relacionadas con el agua
# 4    Las políticas relacionadas con el agua
# ..                                      ...
# 107  Las políticas relacionadas con el agua
# ...
