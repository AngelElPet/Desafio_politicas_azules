# %%
import pandas as pd

em = pd.read_csv('agua_embalsamada_CCAA_15052023')
hog = pd.read_csv('agua_hogares_CCAA_2000-2020')
res = pd.read_csv('aguas_residuales_CCAA_2000-2020')

# %%
poblacion = pd.read_csv('poblacion.csv', sep = ';')

# %%
del(poblacion['Sexo'])

# %%
del(poblacion['Nacional'])

# %%
poblacion['Comunidades y Ciudades Autonomas'].fillna('Total', inplace=True)
poblacion.fillna(0,inplace=True)

# %%
len(poblacion['Periodo'].unique())
# Out:
# 26

# %%
df_poblacion = pd.DataFrame(lista,columns=['Provincia'])

# %%
lista = []
for x in poblacion['Comunidades y Ciudades Autonomas'].unique():
    lista.append(x[3:])

lista = lista[:-1]
lista[-1] = 'Ceuta y Melilla'
len(lista)
# Out:
# 19

# %%
import numpy as np

# %%
len(lista1[0])
# Out:
# 20

# %%
for x in range(len(lista1))

# %%
len(lista1)
# Out:
# 25

# %%
lista1 = []
for x in range(26):
    lista1.append([])
z = np.array(poblacion.Total)
a = 0
for x in range(len(z)):
    
    lista1[a].append(z[x])
    
    a = a +1
    if a ==26:
        a=0

# %%
len(poblacion.Total)/20
# Out:
# 26.0

# %%
poblacion.head()
# Out:
#    Comunidades y Ciudades Autonomas  Periodo      Total
# 26                     01 Andalucia     2021  8.472.407
# 27                     01 Andalucia     2020  8.464.411
# 28                     01 Andalucia     2019  8.414.240
# 29                     01 Andalucia     2018  8.384.408
# 30                     01 Andalucia     2017  8.379.820

# %% [markdown]
# # Embalsada
#
# Volumen en hm^3

# %%
em.head()
# Out:
#   Comunidad  Capacidad  Embalsamada  Porcentaje embalsamada  Variación  \
# 0     Alava        223          167                   74.89          3
# 1  Albacete        727          264                   36.31         -5
# 2  Alicante        315           99                   31.43         -1
# 3   Almeria        224           26                   11.61         -1
# 4  Asturias        456          389                   85.31         12
#
#    Porcentaje Variación
# 0                  1.35
# 1                 -0.69
# 2                 -0.32
# 3                 -0.45
# 4                  2.63

# %%
print(em.info())
print(em.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Comunidad               46 non-null     object
#  1   Capacidad               46 non-null     int64
#  2   Embalsamada             46 non-null     int64
#  3   Porcentaje embalsamada  46 non-null     float64
#  4   Variación               46 non-null     int64
#  5   Porcentaje Variación    46 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 2.3+ KB
# None
#          Capacidad  Embalsamada  Porcentaje embalsamada  Variación  \
# count    46.000000    46.000000               46.000000  46.000000
# mean   1218.891304   587.673913               53.710217  -8.347826
# std    1577.076271   823.410038               22.492856  13.760196
# min       6.000000     6.000000               11.610000 -63.000000
# ...

# %% [markdown]
# # Hogares
#
# Volumen en miles de metros cúbicos al día

# %%
print(hog.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Provincia  19 non-null     object
#  1   2020       19 non-null     int64
#  2   2018       19 non-null     int64
#  3   2016       19 non-null     int64
#  4   2014       19 non-null     int64
#  5   2013       19 non-null     int64
#  6   2012       19 non-null     int64
#  7   2011       19 non-null     int64
#  8   2010       19 non-null     int64
#  9   2009       19 non-null     int64
#  10  2008       19 non-null     int64
#  11  2007       19 non-null     int64
#  12  2006       19 non-null     int64
#  13  2005       19 non-null     int64
#  14  2004       19 non-null     int64
#  15  2003       19 non-null     int64
#  16  2002       19 non-null     int64
#  17  2001       19 non-null     int64
#  18  2000       19 non-null     int64
# dtypes: int64(18), object(1)
# ...

# %%
print(hog.describe())
# Out:
#                2020          2018          2016          2014          2013  \
# count  1.900000e+01  1.900000e+01  1.900000e+01  1.900000e+01  1.900000e+01
# mean   2.411368e+05  2.390742e+05  2.418265e+05  2.355522e+05  2.334406e+05
# std    5.114737e+05  5.061776e+05  5.117146e+05  4.982976e+05  4.932083e+05
# min    7.523000e+03  7.553000e+03  6.397000e+03  6.484000e+03  6.488000e+03
# 25%    4.834000e+04  5.066500e+04  5.347550e+04  5.026750e+04  5.177350e+04
# 50%    8.235600e+04  8.215000e+04  8.862200e+04  9.189900e+04  9.780200e+04
# 75%    2.089155e+05  2.156675e+05  2.144230e+05  2.214430e+05  2.148950e+05
# max    2.290800e+06  2.271205e+06  2.297352e+06  2.237746e+06  2.217686e+06
#
#                2012          2011          2010          2009          2008  \
# count  1.900000e+01  1.900000e+01  1.900000e+01  1.900000e+01  1.900000e+01
# mean   2.430392e+05  2.509880e+05  2.539693e+05  2.625097e+05  2.673569e+05
# ...

# %%
hog.head()
# Out:
#                       Provincia   2020   2018   2016   2014   2013   2012  \
# 18              Ceuta y Melilla   7523   7553   6397   6484   6488   6608
# 17                    Rioja, La  14276  13259  13074  12180  12967  15219
# 15  Navarra, Comunidad Foral de  28750  26798  25986  25757  26088  29374
# 6                     Cantabria  35176  36437  32789  32441  31010  32660
# 4                Balears, Illes  51788  52131  55955  50653  57174  53045
#
#      2011   2010   2009   2008   2007   2006   2005   2004   2003   2002  \
# 18   9298   8727   6552   6869   6830   7298   7124   7397   7251   7750
# 17  14016  13950  15121  17190  17024  16600  15955  15113  14257  14355
# 15  30672  28889  30289  28878  27361  28079  28982  30745  32303  30798
# 6   34045  36505  37837  39128  38809  41682  39225  37880  37118  35980
# 4   49458  47470  49697  52986  50516  54919  49879  49518  44939  42567
#
#      2001   2000         Media
# 18   7970   7897   7334.222222
# ...

# %%
hog = hog.iloc[1:,:]

# %%
Media = []
a=0
for y in range(len( hog['Provincia'])):
    for x in range(len(hog.columns)-1):
        a =a +hog.iloc[y,x+1]
    Media.append(a/len(hog['Provincia']))
    a=0

hog['Media'] = Media

# %%
import matplotlib.pyplot as plt
for t in hog.columns[1:]:
    hog = hog.sort_values(t,ascending=True)
    hog.head()
    x = hog[t]

    plt.figure(figsize=(7,7))
    plt.hlines(y = hog['Provincia'], xmin = min(x)-10000, xmax= max(x), color ='skyblue')
    plt.title('Año ' + t)
    plt.plot(x,hog['Provincia'],'o');

# %% [markdown]
# # Residuales
#
# Recogida y tratamiento de las aguas residuales por comunidades y ciudades autónomas, tipo de indicador y periodo
#
# Unidades: Volumen : metros cúbicos/día. Importe miles de euros. Longitud Kilometros

# %%
res.head()
# Out:
#                       Provincia    2020    2018    2016    2014    2013  \
# 17                    Rioja, La  179071  160431  151978  148053  163030
# 14            Murcia, Región de  313800  283869  356164  363900  302171
# 6                     Cantabria  293290  349650  319351  266992  286585
# 3       Asturias, Principado de  446555  370603  403460  552204  451120
# 15  Navarra, Comunidad Foral de  286610  295282  209822  215947  226908
#
#       2012    2011    2010    2009    2008    2007    2006    2005    2004  \
# 17  138318  143770  143244  183732  195047  247557  245362  268906  284046
# 14  298630  315288  303283  303319  288243  285956  293788  338710  290694
# 6   257359  245869  279236  243190  254799  223436  283538  287291  204618
# 3   409599  367351  335400  298913  273866  285462  327610  296015  267259
# 15  192638  189806  207969  225018  313229  366868  348483  336520  329649
#
#       2003    2002    2001    2000
# 17   56096   83811   70800   52650
# ...

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Provincia  19 non-null     object
#  1   2020       19 non-null     int64
#  2   2018       19 non-null     int64
#  3   2016       19 non-null     int64
#  4   2014       19 non-null     int64
#  5   2013       19 non-null     int64
#  6   2012       19 non-null     int64
#  7   2011       19 non-null     int64
#  8   2010       19 non-null     int64
#  9   2009       19 non-null     int64
#  10  2008       19 non-null     int64
#  11  2007       19 non-null     int64
#  12  2006       19 non-null     int64
#  13  2005       19 non-null     int64
#  14  2004       19 non-null     int64
#  15  2003       19 non-null     int64
#  16  2002       19 non-null     int64
#  17  2001       19 non-null     int64
#  18  2000       19 non-null     int64
# dtypes: int64(18), object(1)
# ...

# %%
res.describe()
# Out:
#                2020          2018          2016          2014          2013  \
# count  1.900000e+01  1.900000e+01  1.900000e+01  1.900000e+01  1.900000e+01
# mean   1.406489e+06  1.440483e+06  1.363061e+06  1.425272e+06  1.441436e+06
# std    2.951372e+06  3.024208e+06  2.859436e+06  2.989172e+06  3.025083e+06
# min    4.277600e+04  4.193700e+04  4.085800e+04  4.553500e+04  4.424700e+04
# 25%    3.117425e+05  3.185735e+05  3.305600e+05  3.495465e+05  3.161785e+05
# 50%    5.336750e+05  4.785920e+05  4.983370e+05  5.522040e+05  5.578710e+05
# 75%    1.206314e+06  1.311242e+06  1.167514e+06  1.158514e+06  1.150614e+06
# max    1.336164e+07  1.368459e+07  1.294908e+07  1.354008e+07  1.369364e+07
#
#                2012          2011          2010          2009          2008  \
# count  1.900000e+01  1.900000e+01  1.900000e+01  1.900000e+01  1.900000e+01
# mean   1.430764e+06  1.420791e+06  1.402821e+06  1.347471e+06  1.302264e+06
# ...

# %%
res = res.iloc[1:]

# %%
res.iloc[2,2]
# Out:
# 370603

# %%
len(res['Provincia'])
# Out:
# 18

# %%
Media = []
a=0
for y in range(len( res['Provincia'])):
    for x in range(len(res.columns)-1):
        a =a +res.iloc[y,x+1]
    Media.append(a/len(res['Provincia']))
    a=0

res['Media'] = Media

# %%
res.head()
# Out:
#                  Provincia     2020     2018     2016     2014     2013  \
# 1                Andalucía  1915525  2113908  1912804  2005740  2073031
# 2                   Aragón   533675   478592   526337   552592   557871
# 3  Asturias, Principado de   446555   370603   403460   552204   451120
# 4           Balears, Illes   309685   341865   313241   335193   396379
# 5                 Canarias   318386   282590   341769   382674   330186
#
#       2012     2011     2010     2009     2008     2007     2006     2005  \
# 1  2330840  2256741  1838496  1566714  1488514  1387265  1767317  1745600
# 2   512896   549061   649614   677212   617991   590011   552921   580191
# 3   409599   367351   335400   298913   273866   285462   327610   296015
# 4   394772   377398   280047   301103   291718   323705   367836   452976
# 5   367286   341566   339630   357252   340174   297974   297054   258900
#
#       2004     2003     2002     2001     2000
# ...

# %%
import matplotlib.pyplot as plt
for t in res.columns[1:]:
    res = res.sort_values(t,ascending=True)
    res.head()
    x = res[t]

    plt.figure(figsize=(5,5))
    plt.hlines(y = res['Provincia'], xmin = min(x)-10000, xmax= max(x), color ='skyblue')
    plt.title('Año ' + t)
    plt.plot(x,res['Provincia'],'o');
